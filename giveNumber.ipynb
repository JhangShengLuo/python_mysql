# %%
giveNum=[]

with open('fullCombined0722.txt','r')as f:
    for ele in f.readlines():
        giveNum.append(format(ele).decode('utf8').strip('\n'+'\r').split(','))
        
print len(giveNum)

for eleg in range(len(giveNum[1:])):
    for ele in giveNum:
        giveNum.setitem(0,u'n00'+eleg)
        
print len(giveNum)
# Out:
# 884
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-f7d9eeb886cb> in <module>()
#       9 for eleg in range(len(giveNum[1:])):
#      10     for ele in giveNum:
# ---> 11         giveNum.setitem(0,u'n00'+eleg)
#      12
#      13 print len(giveNum)
#
# AttributeError: 'list' object has no attribute 'setitem'

# %%
giveNum=[]
a=0
for line in open('fullCombined0722.txt','r'):
    if (a==0):
        a+=1
        continue
#     giveNum.append(u'A%03d'%(a)+u','+line.decode('utf-8').strip('\n'+'\r').split(',',1)[1])
    print u'A%03d'%(a)+u','+line.decode('utf-8').strip('\n'+'\r').split(',',1)[1]
    a+=1
    
# print len(giveNum)


# with open('sampleNutrition.txt','w')as f:
#     for ele in giveNum:
#         f.write(ele.encode('utf8')+'\n')
    
    
#         print ele,
#     print
    
#     giveNum.append(format(ele).decode('utf8').strip('\n'+'\r').split(','))
        
# print len(giveNum)

# for eleg in range(len(giveNum[1:])):
#     for ele in giveNum:
#         giveNum.setitem(0,u'n00'+eleg)
        
# print len(giveNum)
# Out:
# A001,全麥,367,11.6,9.3,3,74.2,15.3
# A002,麥片,365,12.1,8.6,1.8,76.7,6
# A003,紅藜,360,12.9,12.5,1.5,72.5,1.4
# A004,粟米粒,360,12.9,12.5,1.5,72.5,1.4
# A005,藜麥,362,12.6,14.1,2.6,69.2,11.3
# A006,胚芽,417,4.2,31.4,11.6,47.9,10
# A007,麥芽,417,4.2,31.4,11.6,47.9,10
# A008,麥米片,417,4.2,31.4,11.6,47.9,10
# A009,麵皮,262,33,7.8,0.5,57,1.5
# A010,餃皮,262,33,7.8,0.5,57,1.5
# A011,低筋粉,364,12,8.1,1.2,78.2,2
# A012,麵粉,361,12.6,11.5,1.3,74.1,1.8
# A013,鬆餅粉,361,12.6,11.5,1.3,74.1,1.8
# A014,中筋粉,361,12.6,11.5,1.3,74.1,1.8
# A015,高筋粉,362,12.3,12.9,1.2,73.1,1.9
# A016,全麥粉,359,12.7,13,1.7,71.4,8
# A017,雜糧,359,11.7,13.1,2.3,72,5.7
# A018,白麵,354,10.8,11.5,1.4,74.6,1.9
# A019,乾麵,354,10.8,11.5,1.4,74.6,1.9
# A020,麵條,354,10.8,11.5,1.4,74.6,1.9
# A021,直麵,354,10.8,11.5,1.4,74.6,1.9
# A022,關東麵,359,9,11.4,1.2,76.3,1.1
# A023,油麵,359,9,11.4,1.2,76.3,1.1
# A024,意大利麵,356,11.5,13.8,1.4,72.6,1.8
# A025,管麵,356,11.5,13.8,1.4,72.6,1.8
# A026,通心粉,356,11.5,13.8,1.4,72.6,1.8
# A027,筆管麵,356,11.5,13.8,1.4,72.6,1.8
# ...

# %%
# help(list)
# Out:
# Help on class list in module __builtin__:
#
# class list(object)
#  |  list() -> new empty list
#  |  list(iterable) -> new list initialized from iterable's items
#  |
#  |  Methods defined here:
#  |
#  |  __add__(...)
#  |      x.__add__(y) <==> x+y
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __delslice__(...)
#  |      x.__delslice__(i, j) <==> del x[i:j]
#  |
#  |      Use of negative indices is not supported.
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __getslice__(...)
#  |      x.__getslice__(i, j) <==> x[i:j]
#  |
#  |      Use of negative indices is not supported.
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __iadd__(...)
# ...
